# %% [markdown]
# <a href="https://colab.research.google.com/github/HeatherDriver/MathGraph/blob/main/05_Label_classes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Library imports
from google.colab import drive, userdata
import pickle
import random
import re
import time
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import plotly.express as px
import pprint

# %%
# Mount drive
drive.mount("/content/drive")
# %cd '/content/drive/MyDrive/Colab Notebooks/Math_Graph/pickle_files'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Colab Notebooks/Math_Graph/pickle_files

# %%
# View all pandas columns, rows
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# Define file read function
def read_pickle(dict_file):
  with open(dict_file, 'rb') as file:
    return pickle.load(file)

# Define file write function
def write_pickle(dict_file, dict_file_name):
  dict_file_name = dict_file_name + '.pkl'
  with open(dict_file_name, 'wb') as file:
    pickle.dump(dict_file, file)

# %%
# Read in dictionary
all_data = read_pickle('all_data_matches.pkl')
all_data_amended = all_data.copy()

# %%
random_sample = random.sample(list(all_data_amended.items()), 3)

my_list = []
key, sub_dict = random_sample[0]
my_list.append(sub_dict['tokens'])
my_list.append(sub_dict['baseline_tags'])
my_list.append(sub_dict['input_ids'])
my_list.append(sub_dict['ner_tags'])
print(f"Key: {key}")
print(f"Text: {sub_dict['text']}")

pd.DataFrame(my_list, index=["Tokens", "Baseline_Tags", "Input_ids", "NER_Tags"])
# Out:
# Key: Bôcher's theorem
# Text: Bôcher's theorem is a result in the field of mathematical analysis that provides conditions under which a certain type of series converges uniformly. It primarily deals with the uniform convergence of Fourier series based on the behavior of the function being represented, particularly focusing on the smoothness and continuity of the function. This theorem is significant for ensuring that various operations can be interchangeably applied to the series and the function, such as integration and differentiation.
#                   0                        1      2       3   \
# Tokens         [CLS]                        B    ##ô  ##cher
# Baseline_Tags      O                    B-PER  B-PER   B-PER
# Input_ids        101                      139  28206    6072
# NER_Tags         IGN  B-CALCULUS-AND-ANALYSIS    IGN     IGN
#
#                                     4                        5   \
# Tokens                               '                        s
# Baseline_Tags                        O                        O
# Input_ids                          112                      188
# NER_Tags       I-CALCULUS-AND-ANALYSIS  I-CALCULUS-AND-ANALYSIS
#
#                                     6     7    8       9     10    11  \
# Tokens                         theorem    is    a  result    in   the
# Baseline_Tags                        O     O    O       O     O     O
# Input_ids                        10384  1110  170    1871  1107  1103
# NER_Tags       E-CALCULUS-AND-ANALYSIS     O    O       O     O     O
#
#                       12    13            14                       15    16  \
# Tokens             field    of  mathematical                 analysis  that
# Baseline_Tags          O     O             O                        O     O
# Input_ids           1768  1104          9988                     3622  1115
# NER_Tags       S-ALGEBRA     O             O  S-CALCULUS-AND-ANALYSIS     O
#
#                      17          18     19     20   21       22    23    24  \
# Tokens         provides  conditions  under  which    a  certain  type    of
# Baseline_Tags         O           O      O      O    O        O     O     O
# Input_ids          2790        2975   1223   1134  170     2218  2076  1104
# NER_Tags              O           O      O      O    O        O     O     O
#
#                                     25     26     27     28       29    30  \
# Tokens                          series    con  ##ver  ##ges  uniform  ##ly
# Baseline_Tags                        O      O      O      O        O     O
# Input_ids                         1326  14255   4121   7562     6029  1193
# NER_Tags       S-CALCULUS-AND-ANALYSIS      O      O      O        O     O
#
#                 31    32         33     34    35    36       37  \
# Tokens           .    It  primarily  deals  with   the  uniform
# Baseline_Tags    O     O          O      O     O     O        O
# Input_ids      119  1135       3120   8927  1114  1103     6029
# NER_Tags         O     O          O      O     O     O        O
#
#                                     38    39                       40      41  \
# Tokens                     convergence    of                     Four   ##ier
# Baseline_Tags                        O     O                   B-MISC  B-MISC
# Input_ids                        25628  1104                     3396    2852
# NER_Tags       S-CALCULUS-AND-ANALYSIS     O  B-CALCULUS-AND-ANALYSIS     IGN
#
#                                     42     43    44    45        46    47  \
# Tokens                          series  based    on   the  behavior    of
# Baseline_Tags                        O      O     O     O         O     O
# Input_ids                         1326   1359  1113  1103      4658  1104
# NER_Tags       E-CALCULUS-AND-ANALYSIS      O     O     O         O     O
#
#                  48                       49     50           51   52  \
# Tokens          the                 function  being  represented    ,
# Baseline_Tags     O                        O      O            O    O
# Input_ids      1103                     3053   1217         2533  117
# NER_Tags          O  S-CALCULUS-AND-ANALYSIS      O            O    O
#
#                          53        54    55    56      57      58    59  \
# Tokens         particularly  focusing    on   the  smooth  ##ness   and
# Baseline_Tags             O         O     O     O       O       O     O
# Input_ids              2521      7781  1113  1103    5307    1757  1105
# NER_Tags                  O         O     O     O       O       O     O
#
#                                     60    61    62        63   64    65  \
# Tokens                      continuity    of   the  function    .  This
# Baseline_Tags                        O     O     O         O    O     O
# Input_ids                        15126  1104  1103      3053  119  1188
# NER_Tags       S-CALCULUS-AND-ANALYSIS     O     O         O    O     O
#
#                     66    67           68    69        70    71       72  \
# Tokens         theorem    is  significant   for  ensuring  that  various
# Baseline_Tags        O     O            O     O         O     O        O
# Input_ids        10384  1110         2418  1111     13291  1115     1672
# NER_Tags             O     O            O     O         O     O        O
#
#                        73    74    75           76      77       78    79  \
# Tokens         operations   can    be  interchange  ##ably  applied    to
# Baseline_Tags           O     O     O            O       O        O     O
# Input_ids            2500  1169  1129         9629    5382     3666  1106
# NER_Tags                O     O     O            O       O        O     O
#
#                  80      81    82    83        84   85    86    87  \
# Tokens          the  series   and   the  function    ,  such    as
# Baseline_Tags     O       O     O     O         O    O     O     O
# Input_ids      1103    1326  1105  1103      3053  117  1216  1112
# NER_Tags          O       O     O     O         O    O     O     O
#
#                         88    89               90   91     92
# Tokens         integration   and  differentiation    .  [SEP]
# Baseline_Tags            O     O                O    O      O
# Input_ids             9111  1105            23510  119    102
# NER_Tags                 O     O                O    O    IGN

# %%
# Finetune definitions
# dict_file_name = 'train_definitions.pkl'
# train_definitions = read_pickle(dict_file_name)

# key, sub_dict = random_sample[0]
# # all_data_amended["Kobon Triangle"]['ner_tags'][68] = 'O'
# # all_data_amended["Kobon Triangle"]['ner_tags'][69] = 'O'

# # train_definitions.update({key: all_data_amended[key]})

# dict_file_name = 'train_definitions.pkl'
# with open(dict_file_name, 'wb') as file:
#   pickle.dump(train_definitions, file)

# # Train definitions has the hand-labelled definitions
# train_definitions = read_pickle(dict_file_name)
# train_definitions.keys()

# %% [markdown]
# ## Class distribution by main tag

# %%
# Function to count the tag definition per tag-list
def returns_count_per_class(ner_tag_list):
  my_dict = {}
  for tag in ner_tag_list:
    if tag not in ['O', 'IGN']:
      tag = '-'.join(tag.split('-')[1:])
    if tag not in my_dict:
      my_dict[tag] = 1
    else:
      my_dict[tag] += 1
  sorted_data = dict(sorted(my_dict.items(), key=lambda item: item[1], reverse=True))
  return sorted_data

# %%
# Function to summarise main tags
def returns_main_tags(all_data_amended):
  name, count_list, no_tag_list = [], [], []

  for key, sub_dict in all_data_amended.items():
    my_list, my_list_i = [],[]
    to_count = sub_dict['ner_tags']
    count = returns_count_per_class(to_count)

    for i, (k, v) in enumerate(count.items()):
      if k in ['O', 'IGN']:
        continue
      else:
        my_list.append(k)
        my_list_i.append(key)
    try:
      count_list.append(my_list[0])
      name.append(my_list_i[0])
    except:
      no_tag_list.append(key)
      continue

  for_df = {'name': name, 'main_concept': count_list}
  df = pd.DataFrame(for_df)
  summary = df[['main_concept']].groupby('main_concept').value_counts().reset_index(drop=False)
  summary = summary.sort_values(by="count", ascending=False).reset_index(drop=True)
  return summary, df, no_tag_list

# %%
summary, label_df, no_tag_list = returns_main_tags(all_data_amended)

for tag in no_tag_list:
  try:
    del all_data_amended[tag]
  except:
    continue

assert len(all_data_amended) == label_df.shape[0], 'Error'

# %%
fig = px.bar(summary, x='main_concept', y='count', hover_data=['main_concept', 'count'], text='count', color='count', height=500, color_continuous_scale='Viridis', title="Distribution by primary classification label")
fig.update_coloraxes(showscale=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4ef2d71b-b618-4233-8922-e98876a3ada9" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4ef2d71b-b618-4233-8922-e98876a3ada9")) {                    Plotly.newPlot(                        "4ef2d71b-b618-4233-8922-e98876a3ada9",                        [{"alignmentgroup":"True","hovertemplate":"main_concept=%{x}\u003cbr\u003ecount=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[3386,2274,1706,1670,1433,1367,1230,651,564,504,258,93,76,62,60,52,51,50,45,35,20,14,11,11,11,10,9,1],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[3386.0,2274.0,1706.0,1670.0,1433.0,1367.0,1230.0,651.0,564.0,504.0,258.0,93.0,76.0,62.0,60.0,52.0,51.0,50.0,45.0,35.0,20.0,14.0,11.0,11.0,11.0,10.0,9.0,1.0],"textposition":"auto","x":["CALCULUS-AND-ANALYSIS","NUMBER-THEORY","TOPOLOGY","ALGEBRA","GEOMETRY","DISCRETE-MATHEMATICS","PROBABILITY-AND-STATISTICS","APPLIED-MATHEMATICS","RECREATIONAL-MATHEMATICS","FOUNDATIONS-OF-MATHEMATICS","MATRIX-TYPES","MATRIX-OPERATIONS","LINEAR-ALGEBRA","MATRIX-PROPERTIES","MATRIX-EIGENVALUES","ORG","DETERMINANTS","INTEGER-MATRICES","LIE-ALGEBRA","LOC","LINEAR-SYSTEMS-OF-EQUATIONS","MATRIX-NORMS","MATRIX-GROUPS","MATRIX-INVERSION","LIE-GROUPS","MATRIX-DECOMPOSITION","MATRICES","LIE-THEORY"],"xaxis":"x","y":[3386,2274,1706,1670,1433,1367,1230,651,564,504,258,93,76,62,60,52,51,50,45,35,20,14,11,11,11,10,9,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22222222 ...

# %% [markdown]
# ### Merging labels together

# %%
# Condense matrix classifications to single classification = "MATRICES"

b_tags = ["B-MATRIX-DECOMPOSITION", "B-MATRIX-EIGENVALUES", "B-MATRIX-GROUPS", "B-MATRIX-INVERSION", "B-MATRIX-NORMS", "B-MATRIX-OPERATIONS", "B-MATRIX-PROPERTIES", "B-MATRIX-TYPES", "B-INTEGER-MATRICES"]
i_tags = ["I-MATRIX-DECOMPOSITION","I-MATRIX-EIGENVALUES","I-MATRIX-GROUPS","I-MATRIX-INVERSION","I-MATRIX-NORMS","I-MATRIX-OPERATIONS","I-MATRIX-PROPERTIES","I-MATRIX-TYPES", "I-INTEGER-MATRICES"]
e_tags = ["E-MATRIX-DECOMPOSITION","E-MATRIX-EIGENVALUES","E-MATRIX-GROUPS","E-MATRIX-INVERSION","E-MATRIX-NORMS","E-MATRIX-OPERATIONS","E-MATRIX-PROPERTIES","E-MATRIX-TYPES", "E-INTEGER-MATRICES"]
s_tags = ["S-MATRIX-DECOMPOSITION","S-MATRIX-EIGENVALUES","S-MATRIX-GROUPS","S-MATRIX-INVERSION","S-MATRIX-NORMS","S-MATRIX-OPERATIONS","S-MATRIX-PROPERTIES","S-MATRIX-TYPES", "S-INTEGER-MATRICES"]
lie_b_tags = ["B-LIE-GROUPS", "B-LIE-THEORY"]
lie_i_tags = ["I-LIE-GROUPS", "I-LIE-THEORY"]
lie_e_tags = ["E-LIE-GROUPS", "E-LIE-THEORY"]
lie_s_tags = ["S-LIE-GROUPS", "S-LIE-THEORY"]

for i, (key, sub_dict) in enumerate(all_data_amended.items()):
  ner_tags = sub_dict['ner_tags']
  for ner_tag in ner_tags:
    if ner_tag in b_tags:
      ner_tags[ner_tags.index(ner_tag)] = "B-MATRICES"
    elif ner_tag in i_tags:
      ner_tags[ner_tags.index(ner_tag)] = "I-MATRICES"
    elif ner_tag in e_tags:
      ner_tags[ner_tags.index(ner_tag)] = "E-MATRICES"
    elif ner_tag in s_tags:
      ner_tags[ner_tags.index(ner_tag)] = "S-MATRICES"
    elif ner_tag in lie_b_tags:
      ner_tags[ner_tags.index(ner_tag)] = "B-LIE-ALGEBRA"
    elif ner_tag in lie_i_tags:
      ner_tags[ner_tags.index(ner_tag)] = "I-LIE-ALGEBRA"
    elif ner_tag in lie_e_tags:
      ner_tags[ner_tags.index(ner_tag)] = "E-LIE-ALGEBRA"
    elif ner_tag in lie_s_tags:
      ner_tags[ner_tags.index(ner_tag)] = "S-LIE-ALGEBRA"
  all_data_amended[key]['ner_tags'] = ner_tags

summary, label_df, no_tag_list = returns_main_tags(all_data_amended)
label_df = label_df.reset_index(drop=False)
fig = px.bar(summary, x='main_concept', y='count', hover_data=['main_concept', 'count'], text='count', color='count', height=500, color_continuous_scale='Viridis', title="Distribution by primary classification label")
fig.update_coloraxes(showscale=False)
fig.update_layout(autosize=False, width=1600, height=700, margin=dict( l=50, r=50, b=100, t=100, pad=4 ), font=dict(size=12))
fig.write_image("/content/drive/MyDrive/Colab Notebooks/Math_Graph/Images/fig1.png")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4a4e5a8e-3bc9-4cba-977a-9a8702904bef" class="plotly-graph-div" style="height:700px; width:1600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4a4e5a8e-3bc9-4cba-977a-9a8702904bef")) {                    Plotly.newPlot(                        "4a4e5a8e-3bc9-4cba-977a-9a8702904bef",                        [{"alignmentgroup":"True","hovertemplate":"main_concept=%{x}\u003cbr\u003ecount=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[3368,2272,1703,1653,1427,1363,1229,645,633,562,504,76,64,52,48,35,20],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[3368.0,2272.0,1703.0,1653.0,1427.0,1363.0,1229.0,645.0,633.0,562.0,504.0,76.0,64.0,52.0,48.0,35.0,20.0],"textposition":"auto","x":["CALCULUS-AND-ANALYSIS","NUMBER-THEORY","TOPOLOGY","ALGEBRA","GEOMETRY","DISCRETE-MATHEMATICS","PROBABILITY-AND-STATISTICS","APPLIED-MATHEMATICS","MATRICES","RECREATIONAL-MATHEMATICS","FOUNDATIONS-OF-MATHEMATICS","LINEAR-ALGEBRA","LIE-ALGEBRA","ORG","DETERMINANTS","LOC","LINEAR-SYSTEMS-OF-EQUATIONS"],"xaxis":"x","y":[3368,2272,1703,1653,1427,1363,1229,645,633,562,504,76,64,52,48,35,20],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{ ...

# %%
# Check order of label_df same as all_data_amended (NB for indices for train-test split)
for i, key in enumerate(list(all_data_amended.keys())):
  assert label_df.iloc[i]['name'] == key, 'Error'

label_df.head()
# Out:
#    index                        name           main_concept
# 0      0  ludwig's inversion formula  CALCULUS-AND-ANALYSIS
# 1      1                    quotient          NUMBER-THEORY
# 2      2          survivorship curve    APPLIED-MATHEMATICS
# 3      3                inadmissible   DISCRETE-MATHEMATICS
# 4      4      Natural Logarithm of 2   DISCRETE-MATHEMATICS

# %% [markdown]
# ## Train-test stratified split

# %%
X_train_indices, X_test_indices, y_train_indices, y_test_indices = train_test_split(label_df['index'].to_numpy(), label_df['main_concept'].to_numpy(),
                                                                                    test_size=0.3, random_state=42, stratify=label_df['main_concept'].to_numpy())

# Repeat to get validation sub-sample of Train
X_train_indices, X_valid_indices, y_train_indices, y_valid_indices = train_test_split(X_train_indices, y_train_indices, test_size=0.3, random_state=42, stratify=y_train_indices)

# %%
# Check the resulting distributions
print("Class distribution in original dataset:")
print(label_df['main_concept'].value_counts(normalize=True))

print("\nClass distribution in train dataset:")
print(pd.Series(y_train_indices).value_counts(normalize=True))

print("\nClass distribution in validation dataset:")
print(pd.Series(y_valid_indices).value_counts(normalize=True))
# Out:
# Class distribution in original dataset:
# main_concept
# CALCULUS-AND-ANALYSIS          0.215153
# NUMBER-THEORY                  0.145139
# TOPOLOGY                       0.108790
# ALGEBRA                        0.105596
# GEOMETRY                       0.091159
# DISCRETE-MATHEMATICS           0.087070
# PROBABILITY-AND-STATISTICS     0.078510
# APPLIED-MATHEMATICS            0.041204
# MATRICES                       0.040437
# RECREATIONAL-MATHEMATICS       0.035901
# FOUNDATIONS-OF-MATHEMATICS     0.032196
# LINEAR-ALGEBRA                 0.004855
# LIE-ALGEBRA                    0.004088
# ORG                            0.003322
# DETERMINANTS                   0.003066
# LOC                            0.002236
# LINEAR-SYSTEMS-OF-EQUATIONS    0.001278
# Name: proportion, dtype: float64
#
# Class distribution in train dataset:
# CALCULUS-AND-ANALYSIS          0.215152
# NUMBER-THEORY                  0.145130
# TOPOLOGY                       0.108750
# ALGEBRA                        0.105620
# GEOMETRY                       0.091146
# DISCRETE-MATHEMATICS           0.087104
# PROBABILITY-AND-STATISTICS     0.078498
# APPLIED-MATHEMATICS            0.041205
# MATRICES                       0.040422
# RECREATIONAL-MATHEMATICS       0.035859
# FOUNDATIONS-OF-MATHEMATICS     0.032208
# LINEAR-ALGEBRA                 0.004825
# LIE-ALGEBRA                    0.004042
# ORG                            0.003260
# DETERMINANTS                   0.003129
# LOC                            0.002347
# LINEAR-SYSTEMS-OF-EQUATIONS    0.001304
# Name: proportion, dtype: float64
#
# Class distribution in validation dataset:
# CALCULUS-AND-ANALYSIS          0.215024
# NUMBER-THEORY                  0.145073
# TOPOLOGY                       0.108881
# ALGEBRA                        0.105535
# GEOMETRY                       0.091241
# DISCRETE-MATHEMATICS           0.086983
# PROBABILITY-AND-STATISTICS     0.078467
# APPLIED-MATHEMATICS            0.041363
# MATRICES                       0.040450
# RECREATIONAL-MATHEMATICS       0.035888
# FOUNDATIONS-OF-MATHEMATICS     0.032238
# LINEAR-ALGEBRA                 0.004866
# LIE-ALGEBRA                    0.004258
# ORG                            0.003345
# DETERMINANTS                   0.003041
# LOC                            0.002129
# LINEAR-SYSTEMS-OF-EQUATIONS    0.001217
# Name: proportion, dtype: float64

# %%
write_pickle(all_data_amended, 'all_data_amended')

# %%
indices = [X_train_indices, X_test_indices, y_train_indices, y_test_indices, X_valid_indices, y_valid_indices]
names = ['X_train_indices', 'X_test_indices', 'y_train_indices', 'y_test_indices', 'X_valid_indices', 'y_valid_indices']

for idx, name in zip(indices, names):
  write_pickle(idx, name)
