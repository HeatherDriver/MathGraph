# %%
! pip install umap-learn -U kaleido
# Out:
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.11/dist-packages (0.5.7)
# Requirement already satisfied: kaleido in /usr/local/lib/python3.11/dist-packages (0.2.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (1.6.1)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (0.61.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.11/dist-packages (from umap-learn) (0.5.13)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from umap-learn) (4.67.1)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.2->umap-learn) (0.44.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.11/dist-packages (from pynndescent>=0.5->umap-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.22->umap-learn) (3.5.0)

# %%
from google.colab import drive, userdata
import pickle
from openai import OpenAI
import random
from tqdm import tqdm
import time
import numpy as np
import pandas as pd
import re
from umap import UMAP
from transformers import DistilBertTokenizer, DistilBertModel
import torch
from sklearn.preprocessing import MinMaxScaler
import plotly.express as px

# %%
# Mount drive
drive.mount("/content/drive")
# %cd '/content/drive/MyDrive/Colab Notebooks/Math_Graph/pickle_files'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Colab Notebooks/Math_Graph/pickle_files

# %%
# Define file read function
def read_pickle(dict_file):
  with open(dict_file, 'rb') as file:
    return pickle.load(file)

# %%
# Load the tokenizer and finetuned model
model_name = "Heather-Driver/distilbert-NER-LinearAlg-finetuned"
tokenizer = DistilBertTokenizer.from_pretrained(model_name)
model = DistilBertModel.from_pretrained(model_name)

# Set model to evaluation mode
model.eval()
# Out:
# DistilBertModel(
#   (embeddings): Embeddings(
#     (word_embeddings): Embedding(28996, 768, padding_idx=0)
#     (position_embeddings): Embedding(512, 768)
#     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (transformer): Transformer(
#     (layer): ModuleList(
#       (0-5): 6 x TransformerBlock(
#         (attention): DistilBertSdpaAttention(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (q_lin): Linear(in_features=768, out_features=768, bias=True)
#           (k_lin): Linear(in_features=768, out_features=768, bias=True)
#           (v_lin): Linear(in_features=768, out_features=768, bias=True)
#           (out_lin): Linear(in_features=768, out_features=768, bias=True)
#         )
#         (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (ffn): FFN(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (lin1): Linear(in_features=768, out_features=3072, bias=True)
#           (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           (activation): GELUActivation()
#         )
#         (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       )
#     )
#   )
# )

# %%
try:
  lin_alg_df_merg_embeddings = read_pickle('lin_alg_embeddings.pkl')
except FileNotFoundError:
  embedding_list = []

  for sentence in tqdm(lin_alg_df_merged['Sentence'], desc="Processing sentences"):
    inputs = tokenizer(sentence, return_tensors="pt", padding=True, truncation=True) # Get inpput_ids and attention mask
    # inputs = {k : v.to(device) for k, v in encoded_inputs.items()}
    with torch.no_grad():
      outputs = model(**inputs) # No gradient calc -> speeds things up
      cls_embedding = outputs.last_hidden_state[:,0] # get the embedding for the CLS token (first token)
      embedding_list.append(cls_embedding.cpu().numpy())
  lin_alg_df_merged['label_embedding'] = embedding_list
  lin_alg_df_merg_embeddings = lin_alg_df_merged
  with open('lin_alg_definitions.pkl', 'wb') as file:
    pickle.dump(lin_alg_df_merg_embeddings, file)

# %%
lin_alg_df_merg_embeddings.head(2)
# Out:
#                                             Sentence  \
# 0  An involutive Banach algebra is primarily char...
# 1  Involutive Banach algebras are significantly u...
#
#                      Subject         Predicate  \
# 0  involutive banach algebra  characterized by
# 1  involutive banach algebra           used in
#
#                                               Object       Label  \
# 0  the existence of an involution operation that ...  defined as
# 1                                functional analysis     used in
#
#                                      label_embedding
# 0  [[-0.12714861, -0.17931628, 0.2756023, -0.6379...
# 1  [[-0.12393479, -0.23532511, 0.25136113, -0.583...

# %%
X_scaled = MinMaxScaler().fit_transform(np.vstack(lin_alg_df_merg_embeddings['label_embedding'].to_numpy()))

# UMAP to create labels on lower datata manifold
mapper = UMAP(n_components=2, metric="cosine").fit(X_scaled)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.

# %%
# %cd '/content/drive/MyDrive/Colab Notebooks/Math_Graph/03-Predicate'
# Out:
# /content/drive/MyDrive/Colab Notebooks/Math_Graph/03-Predicate

# %%
my_df = pd.DataFrame(mapper.embedding_, columns=['umap_x', 'umap_y'])
my_df['label'] = lin_alg_df_merg_embeddings['Label']
my_df['sentence'] = lin_alg_df_merg_embeddings['Sentence']
my_df['subject'] = lin_alg_df_merg_embeddings['Subject']
my_df = my_df.sort_values(by=['label'])

fig = px.scatter(my_df, x="umap_x", y="umap_y", color=str("label"), hover_data=['sentence'], facet_col="label", facet_col_wrap=3, color_discrete_sequence=px.colors.qualitative.Vivid,
                 width=1200, height=1300)
fig.write_image("UMAP_Pretraining.png")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="28d3e190-6f81-473d-8240-78b40d1c332b" class="plotly-graph-div" style="height:1300px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("28d3e190-6f81-473d-8240-78b40d1c332b")) {                    Plotly.newPlot(                        "28d3e190-6f81-473d-8240-78b40d1c332b",                        [{"customdata":[["The invertible matrix theorem has components that include conditions such as full rank, the existence of unique solutions for linear systems, and linear independence of the column vectors."],["An orthonormal basis is a component of a Hilbert space that allows for efficient representation of vectors within that space."],["The refined alternating sign matrix conjecture is part of a broader mathematical framework that explores the properties and configurations of certain matrix arrangements."],["The invariant factor is a critical component in the classification of finitely generated modules over a principal ideal domain, helping to distinguish modules by their unique structure."],["The concept of dual vector space has components that include both the original vector space and the linear functionals that define relationships between vectors and scalars."],["Patterns generated by elementary cellular automata can be part of the foundation for understanding complex systems and emergent behavior in computational theory."],["The Gerschgorin circle theorem is a powerful tool that helps in locating the eigenvalues of a matrix by establishing bounds based on the entries of the matrix and their respective row sums."],["The adjacency matrix is part of the broader study of graph theory and is essential for algorithms that analyze graph properties."],["The Lorenz Curve is part of the foundation for understanding economic inequality by showing how far the distribution of resources deviates from perfect equality."],["Elementary matrices are part of the foundation for understanding matrix transformations and their effects on vector spaces."],["In certain geometric applications, diagonal points have subclasses that categorize them based on their unique characteristics and functions within symmetrical shapes."],["Diagonal points are derived from the concept of geometric transformations that include rotations and reflections, where specific points maintain their positions relative to the diagonal axis."],["The concepts within the Paley Class are part of the foundation for developing efficient algorithms in cryptography and error detection techniques."],["Le Paige's Theorem has components that include probabilistic models and decision trees to evaluate various outcomes and strategies effectively."],["The companion matrix is an essential tool in linear algebra, as it is subclass of matrices that facilitate the computation of eigenvalues associated with polynomials."],["The Euler Brick's existence is **part of the foundation for** understanding integer solutions in three-dimensional geometry and their properties."],["The Fourier matrix is part of the foundation for transforming signals from the time domain to the frequency domain through Fourier analysis."],["The Spectral Theorem has components that include the diagonalizability of normal operators, which ensures that these operators can be represented in a simple form through their eigenvectors."],["The matrix trace is part of the foundation for understanding various properties of matrices, such as their eigenvalues and invariants."],["The concept of a periodic matrix has components that include its specific eigenvalues and eigenvectors which play a crucial role in understanding its behavior over time."],["A conjugate matrix is part of the foundation for understanding how to perform operations that involve complex numbers in li ...

# %%
my_df.to_csv('UMAP_Pretraining.csv', index=False)

# %% [markdown]
# ## Comparing performance of span-trained classifier

# %%
# Load the tokenizer and finetuned model
model_name = "Heather-Driver/distilbert-classn-LinearAlg-finetuned-pred-span-width-5"
tokenizer = DistilBertTokenizer.from_pretrained(model_name)
model = DistilBertModel.from_pretrained(model_name)

# Set model to evaluation mode
model.eval()
# Out:
# DistilBertModel(
#   (embeddings): Embeddings(
#     (word_embeddings): Embedding(28996, 768, padding_idx=0)
#     (position_embeddings): Embedding(512, 768)
#     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (transformer): Transformer(
#     (layer): ModuleList(
#       (0-5): 6 x TransformerBlock(
#         (attention): DistilBertSdpaAttention(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (q_lin): Linear(in_features=768, out_features=768, bias=True)
#           (k_lin): Linear(in_features=768, out_features=768, bias=True)
#           (v_lin): Linear(in_features=768, out_features=768, bias=True)
#           (out_lin): Linear(in_features=768, out_features=768, bias=True)
#         )
#         (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (ffn): FFN(
#           (dropout): Dropout(p=0.1, inplace=False)
#           (lin1): Linear(in_features=768, out_features=3072, bias=True)
#           (lin2): Linear(in_features=3072, out_features=768, bias=True)
#           (activation): GELUActivation()
#         )
#         (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       )
#     )
#   )
# )

# %%
try:
  lin_alg_df_merg_embeddings = read_pickle('/content/drive/MyDrive/Colab Notebooks/Math_Graph/pickle_files/lin_alg_embeddings_trained.pkl')
except FileNotFoundError:
  embedding_list = []

  for sentence in tqdm(lin_alg_df_merged['Sentence'], desc="Processing sentences"):
    inputs = tokenizer(sentence, return_tensors="pt", padding=True, truncation=True) # Get inpput_ids and attention mask
    # inputs = {k : v.to(device) for k, v in encoded_inputs.items()}
    with torch.no_grad():
      outputs = model(**inputs) # No gradient calc -> speeds things up
      cls_embedding = outputs.last_hidden_state[:,0] # get the embedding for the CLS token (first token)
      embedding_list.append(cls_embedding.cpu().numpy())
  lin_alg_df_merged['label_embedding'] = embedding_list
  lin_alg_df_merg_embeddings = lin_alg_df_merged
  with open('lin_alg_embeddings_trained.pkl', 'wb') as file:
    pickle.dump(lin_alg_df_merg_embeddings, file)

# %%
X_scaled = MinMaxScaler().fit_transform(np.vstack(lin_alg_df_merg_embeddings['label_embedding'].to_numpy()))

# UMAP to create labels on lower datata manifold
mapper = UMAP(n_components=2, metric="cosine").fit(X_scaled)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.

# %%
my_df = pd.DataFrame(mapper.embedding_, columns=['umap_x', 'umap_y'])
my_df['label'] = lin_alg_df_merg_embeddings['Label']
my_df['sentence'] = lin_alg_df_merg_embeddings['Sentence']
my_df['subject'] = lin_alg_df_merg_embeddings['Subject']
my_df = my_df.sort_values(by=['label'])

fig = px.scatter(my_df, x="umap_x", y="umap_y", color=str("label"), hover_data=['sentence'], facet_col="label", facet_col_wrap=3, color_discrete_sequence=px.colors.qualitative.Vivid,
                 width=1200, height=1300)
fig.write_image("UMAP_Posttraining.png")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5c694db7-2684-4944-806c-be83f3e0dce3" class="plotly-graph-div" style="height:1300px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5c694db7-2684-4944-806c-be83f3e0dce3")) {                    Plotly.newPlot(                        "5c694db7-2684-4944-806c-be83f3e0dce3",                        [{"customdata":[["The invertible matrix theorem has components that include conditions such as full rank, the existence of unique solutions for linear systems, and linear independence of the column vectors."],["An orthonormal basis is a component of a Hilbert space that allows for efficient representation of vectors within that space."],["The refined alternating sign matrix conjecture is part of a broader mathematical framework that explores the properties and configurations of certain matrix arrangements."],["The invariant factor is a critical component in the classification of finitely generated modules over a principal ideal domain, helping to distinguish modules by their unique structure."],["The concept of dual vector space has components that include both the original vector space and the linear functionals that define relationships between vectors and scalars."],["Patterns generated by elementary cellular automata can be part of the foundation for understanding complex systems and emergent behavior in computational theory."],["The Gerschgorin circle theorem is a powerful tool that helps in locating the eigenvalues of a matrix by establishing bounds based on the entries of the matrix and their respective row sums."],["The adjacency matrix is part of the broader study of graph theory and is essential for algorithms that analyze graph properties."],["The Lorenz Curve is part of the foundation for understanding economic inequality by showing how far the distribution of resources deviates from perfect equality."],["Elementary matrices are part of the foundation for understanding matrix transformations and their effects on vector spaces."],["In certain geometric applications, diagonal points have subclasses that categorize them based on their unique characteristics and functions within symmetrical shapes."],["Diagonal points are derived from the concept of geometric transformations that include rotations and reflections, where specific points maintain their positions relative to the diagonal axis."],["The concepts within the Paley Class are part of the foundation for developing efficient algorithms in cryptography and error detection techniques."],["Le Paige's Theorem has components that include probabilistic models and decision trees to evaluate various outcomes and strategies effectively."],["The companion matrix is an essential tool in linear algebra, as it is subclass of matrices that facilitate the computation of eigenvalues associated with polynomials."],["The Euler Brick's existence is **part of the foundation for** understanding integer solutions in three-dimensional geometry and their properties."],["The Fourier matrix is part of the foundation for transforming signals from the time domain to the frequency domain through Fourier analysis."],["The Spectral Theorem has components that include the diagonalizability of normal operators, which ensures that these operators can be represented in a simple form through their eigenvectors."],["The matrix trace is part of the foundation for understanding various properties of matrices, such as their eigenvalues and invariants."],["The concept of a periodic matrix has components that include its specific eigenvalues and eigenvectors which play a crucial role in understanding its behavior over time."],["A conjugate matrix is part of the foundation for understanding how to perform operations that involve complex numbers in li ...

# %%
my_df.to_csv('UMAP_Posttraining.csv', index=False)

# %%
my_df.head()
# Out:
#          umap_x    umap_y      label  \
# 854   16.318182  4.786982  component
# 1025  18.079285  5.788503  component
# 255   12.888448  5.251451  component
# 709   14.212613  6.945241  component
# 262   17.513166  6.568578  component
#
#                                                sentence  \
# 854   The invertible matrix theorem has components t...
# 1025  An orthonormal basis is a component of a Hilbe...
# 255   The refined alternating sign matrix conjecture...
# 709   The invariant factor is a critical component i...
# 262   The concept of dual vector space has component...
#
#                                          subject
# 854                    invertible matrix theorem
# 1025                           Orthonormal basis
# 255   refined alternating sign matrix conjecture
# 709                             invariant factor
# 262                            Dual Vector Space

# %%
# Summary of direct references
my_dict = dict()
for i, row in my_df.iterrows():
  if row.label in row.sentence:
    my_dict[i] = 1
  elif row.label == 'generalisation' and 'generalize' in row.sentence:
    my_dict[i] = 1
  elif row.label == 'specialization' and 'specialize' in row.sentence:
    my_dict[i] = 1
  elif row.label == 'verification' and 'verif' in row.sentence:
    my_dict[i] = 1
  elif row.label == 'implementation' and 'implement' in row.sentence:
    my_dict[i] = 1
  else:
    my_dict[i] = 0

my_df['direct_ref'] = my_df.index.map(my_dict.get)
my_df['direct_ref'] = my_df['direct_ref'].fillna(0)

# %%
my_df.groupby(['label', 'direct_ref']).size().reset_index(name='Total')
# Out:
#              label  direct_ref  Total
# 0        component           0     71
# 1        component           1     34
# 2      computation           0    250
# 3      computation           1     11
# 4     connected to           0     73
# 5     connected to           1     16
# 6       defined as           0    163
# 7       defined as           1     63
# 8   generalisation           0     21
# 9   generalisation           1     31
# 10  implementation           0     56
# 11  implementation           1    123
# 12      related to           0    269
# 13      related to           1      7
# 14     represented           0    282
# 15     represented           1     24
# 16  specialization           0     56
# 17  specialization           1     45
# 18         used in           0    324
# 19         used in           1     63
# 20    verification           0     31
# 21    verification           1     15
